# %%
import numpy as np
import os
import cv2
import glob
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, BatchNormalization, MaxPooling2D, Dropout, Dense , Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Concatenate
import matplotlib.pyplot as plt

# %%
pneunomial_classes = ["PNEUMONIA"]
NUM_CLASSES = len(pneunomial_classes)
IMG_SIZE = 256

# %%
def load_data(target_size = (IMG_SIZE,IMG_SIZE), img_folder = ""):
    X = []
    Y = []
    for pneumonial_type in pneunomial_classes:

        imgdir = os.path.join(img_folder, pneumonial_type)
        imgnames = os.listdir(imgdir)
        for imgname in imgnames:
            imgpath = os.path.join(imgdir, imgname)
            img = cv2.imread(imgpath)
            img = cv2.resize(img, target_size)
            X.append(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            Y.append(pneunomial_classes.index(pneumonial_type))
    X = np.array(X)
    X = (X.astype(np.float32) - 127.5) / 127.5
    Y = np.array(Y)
    return [X, Y]

# %%
def discriminator(in_shape = (IMG_SIZE,IMG_SIZE,3), n_classes = NUM_CLASSES):
    # label input
    in_label = Input(shape=(1,))
    # embedding for categorical input
    li = Embedding(n_classes, 50)(in_label)
    # scale up to image dimensions with linear activation
    n_nodes = in_shape[0]*in_shape[1]
    li = Dense(n_nodes)(li)
    # reshape to additional channel
    li = Reshape((in_shape[0], in_shape[1],1))(li)
    # image input
    in_image = Input(shape=in_shape)
    # concat label as a channel
    merge = Concatenate()([in_image, li]) # merge.shape = (256, 256, 4)

    # 256 x 256
    x = Conv2D(32, (5,5), padding='same')(merge)
    x = LeakyReLU(alpha=0.2)(x)

    # downsample to 128 x 128
    x = Conv2D(64, (5,5), strides=(2,2), padding='same')(x)
    x = LeakyReLU(alpha=0.2)(x)

    # downsample to 64x64
    x = Conv2D(128, (5,5), strides=(2,2), padding='same')(x)
    x = LeakyReLU(alpha=0.2)(x)

    # downsample to 32x32
    x = Conv2D(256, (5, 5), strides=(2, 2), padding='same')(x)
    x = LeakyReLU(alpha=0.2)(x)

    # downsample to 16x16
    x = Conv2D(512, (5, 5), strides=(2, 2), padding='same')(x)
    x = LeakyReLU(alpha=0.2)(x)

    # downsample to 8x8
    x = Conv2D(1024, (5, 5), strides=(2, 2), padding='same')(x)
    x = LeakyReLU(alpha=0.2)(x)

    # classifier
    x = Flatten()(x)
    x = Dropout(0.4)(x)
    x = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=[in_image, in_label], outputs=x)

    # compile model
    opt = Adam(lr=0.00002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    return model

# %%
def generator(latent_dim = 100, n_classes = NUM_CLASSES):
    in_label = Input(shape=(1,))
    # embedding for categorical input
    li = Embedding(n_classes, 50)(in_label)
    n_nodes = 8*8
    li = Dense(n_nodes)(li)
    # reshape to additional channel
    li = Reshape((8,8,1))(li)
    # image generator input
    in_lat = Input(shape=(latent_dim,))
    # foundation for 6*6 image
    n_nodes = 1023*8*8
    gen = Dense(n_nodes)(in_lat)
    gen = LeakyReLU(alpha=0.2)(gen)
    gen = Reshape((8,8,1023))(gen)
    # merge image gen and label
    merge = Concatenate()([gen, li]) # merge.shape = (8, 8, 1024)

    # upsample to 16x16
    x = Conv2DTranspose(filters=512, kernel_size=(4,4), strides=(2,2), padding='same')(merge)
    x = LeakyReLU(alpha=0.2)(x)

    # upsample to 32x32
    x = Conv2DTranspose(filters=256, kernel_size=(4, 4), strides=(2, 2), padding='same')(x)
    x = LeakyReLU(alpha=0.2)(x)

    # upsample to 64x64
    x = Conv2DTranspose(filters=128, kernel_size=(4, 4), strides=(2, 2), padding='same')(x)
    x = LeakyReLU(alpha=0.2)(x)

    # upsample to 128x128
    x = Conv2DTranspose(filters=64, kernel_size=(4, 4), strides=(2, 2), padding='same')(x)
    x = LeakyReLU(alpha=0.2)(x)

    # upsample to 256x256
    x = Conv2DTranspose(filters=32, kernel_size=(4, 4), strides=(2, 2), padding='same')(x)
    x = LeakyReLU(alpha=0.2)(x)
    
    # output layer 256x256x3
    x = Conv2D(filters=3, kernel_size=(5,5), padding='same', activation='tanh')(x)

    model = Model([in_lat, in_label], x)
    return model

# %%
def define_gan(g_model, d_model):
    # make weights in the discriminator not trainable
    for layer in d_model.layers:
        layer.trainable = False

    # get noise and label inputs from generator model
    gen_noise, gen_label = g_model.input
    # get image output from the generator model
    gen_output = g_model.output
    # connect image output and label input from generator as inputs to discriminator
    gan_output = d_model([gen_output, gen_label])
    # define gan model as taking noise and label and outputting a classification
    model = Model([gen_noise, gen_label], gan_output)
    # compile model
    opt = Adam(lr=0.0001, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt)
    return model

# %%
def generate_real_samples(dataset, n_samples):
    images, labels = dataset
    ix = randint(0, images.shape[0], n_samples)
    X, labels = images[ix], labels[ix]
    y = ones((n_samples, 1))
    return [X, labels], y

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples, n_classes=NUM_CLASSES):
    # generate points in the latent space
    x_input = randn(latent_dim * n_samples)
    # reshape into a batch of inputs for the network
    z_input = x_input.reshape(n_samples, latent_dim)
    # generate labels
    labels = randint(0, n_classes, n_samples)
    return [z_input, labels]

# %%
# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n_samples):
    # generate points in latent space
    z_input, labels_input = generate_latent_points(latent_dim, n_samples)
    # predict outputs
    images = generator.predict([z_input, labels_input])
    # create class labels
    y = zeros((n_samples, 1))
    return [images, labels_input], y

# %%
# functions for recording training history
def save_model(discriminator, generator, gan, save_dir, epoch):
    d_path = os.path.join(save_dir, "discriminator_epoch_" + str(epoch) + ".h5")
    g_path = os.path.join(save_dir, "generator_epoch_" + str(epoch) + ".h5")
    gan_path = os.path.join(save_dir, "gan_epoch_" + str(epoch) + ".h5")
    discriminator.save(d_path)
    generator.save(g_path)
    gan.save(gan_path)

# %%
def generate_image(epoch, save_dir, generator, n_classes=NUM_CLASSES, latent_dim = 100):
    n_samples_each_classes = 5
    labels = []
    for i in range(n_classes):
        tmp_ = [i for _ in range(n_samples_each_classes)]
        labels.extend(tmp_)
    labels = np.array(labels)

    # generate points in the latent space
    x_input = randn(latent_dim * n_classes * n_samples_each_classes)
    # reshape into a batch of inputs for the network
    z_input = x_input.reshape(n_classes * n_samples_each_classes, latent_dim)

    images = generator.predict([z_input, labels])
    images = (images+1)/2.0

    columns = n_samples_each_classes
    rows = n_classes

    fig = plt.figure(figsize=(20, 8))
    for i in range(columns*rows):
        fig.add_subplot(rows, columns, i + 1)
        #plt.imshow(images[i])
        plt.axis('off')
    save_name = 'epoch_' + str(epoch) + '.png'
    plt.savefig(os.path.join(save_dir, save_name))

# %%
def plot_history(dict_, save_dir, epoch):
    d_loss_real = dict_["d_loss_real"]
    d_acc_real = dict_["d_acc_real"]
    d_loss_fake = dict_["d_loss_fake"]
    d_acc_fake = dict_["d_acc_fake"]
    g_loss = dict_["g_loss"]

    fig = plt.figure(figsize=(16, 4))
    fig.add_subplot(1, 3, 1)
    plt.plot(d_loss_real, color='red')
    plt.plot(d_loss_fake, color='blue')
    plt.title('d_loss')
    plt.xlabel("Iteration", fontsize=10)
    plt.ylabel("Loss", fontsize=10)

    fig.add_subplot(1, 3, 2)
    plt.plot(d_acc_real, color='red')
    plt.plot(d_acc_fake, color='blue')
    plt.title('d_acc')
    plt.xlabel("Iteration", fontsize=10)
    plt.ylabel("Acc", fontsize=10)

    fig.add_subplot(1, 3, 3)
    plt.plot(g_loss)
    plt.title('g_loss')
    plt.xlabel("Iteration", fontsize=10)
    plt.ylabel("Loss", fontsize=10)
    plt.legend()
    plt.savefig(os.path.join(save_dir, "epoch_" + str(epoch) + ".png"))

# %%
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=32, save_img_interval = 5, save_model_interval = 20, history_interval = 5):
    subdirs = os.listdir("save")
    new_subdir = os.path.join("save", str(len(subdirs) + 1))
    os.makedirs(new_subdir, exist_ok=False)
    os.makedirs(os.path.join(new_subdir, "history"))
    os.makedirs(os.path.join(new_subdir, "weight"))
    os.makedirs(os.path.join(new_subdir, "image"))
    log_file = os.path.join(new_subdir, "log.txt")
    bat_per_epo = int(dataset[0].shape[0] / n_batch)
    half_batch = int(n_batch / 2)
    # manually enumerate epochs
    dict_history = {"d_loss_real": [], "d_acc_real":[], "d_loss_fake":[], "d_acc_fake":[], "g_loss":[]}
    
    for i in range(n_epochs):
        # enumerate batches over the training set
        tmp_dict = {"d_loss_real": [], "d_acc_real":[], "d_loss_fake":[], "d_acc_fake":[], "g_loss":[]}
        for j in range(bat_per_epo):
            # get randomly selected 'real' samples
            [X_real, labels_real], y_real = generate_real_samples(dataset, half_batch)
            # update discriminator model weights with real samples
            d_loss_real, d_acc_real = d_model.train_on_batch([X_real, labels_real], y_real)
            # generate 'fake' examples
            [X_fake, labels], y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
            # update discriminator model weights with fake samples
            d_loss_fake, d_acc_fake = d_model.train_on_batch([X_fake, labels], y_fake)
            # prepare points in latent space as input for the generator
            [z_input, labels_input] = generate_latent_points(latent_dim, n_batch)
            # create inverted labels for the fake samples
            y_gan = ones((n_batch, 1))
            # update the generator via the discriminator's error
            g_loss = gan_model.train_on_batch([z_input, labels_input], y_gan)

            dict_history["d_loss_real"].append(d_loss_real)
            dict_history["d_acc_real"].append(d_acc_real)
            dict_history["d_loss_fake"].append(d_loss_fake)
            dict_history["d_acc_fake"].append(d_acc_fake)
            dict_history["g_loss"].append(g_loss)
        with open(log_file, 'a') as f:
            f.write("epoch : {}, d_loss_real: {}, d_acc_real: {}, d_loss_fake: {}, d_acc_fake: {}, g_loss: {}\n".format(i, d_loss_real, d_acc_real, d_loss_fake, d_acc_fake, g_loss))
        f.close()
        print("epoch ", i, ": ", "d_loss_real: ", d_loss_real, ", d_acc_real: ", d_acc_real, ", d_loss_fake: ", d_loss_fake, ", d_acc_fake: ", d_acc_fake, ", g_loss: ", g_loss)
        if i % save_img_interval == 0:
            generate_image(epoch=i, save_dir=os.path.join(new_subdir, "image"), generator=g_model, latent_dim=latent_dim)

        if i % save_model_interval == 0:
            save_model(discriminator=d_model, generator=g_model, gan=gan_model, save_dir=os.path.join(new_subdir, "weight"), epoch=i)

        if i % history_interval == 0:
            plot_history(dict_=dict_history, save_dir = os.path.join(new_subdir, "history"), epoch=i)

# %%
n_epoch = 501
batch_size = 128
latent_dim = 100

d_model = discriminator()
g_model = generator()
gan_model = define_gan(g_model, d_model)
dataset = load_data(target_size=(IMG_SIZE,IMG_SIZE), img_folder='/home/ubuntu/teamprj/datasets/chest_xray/train')
train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs= n_epoch, n_batch= batch_size)
# Out:
# /home/ubuntu/teamprj/env/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1002_bacteria_2933.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person56_bacteria_269.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person607_virus_1173.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1551_bacteria_4054.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person23_bacteria_107.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1453_bacteria_3771.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person439_bacteria_1895.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person55_bacteria_262.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person321_bacteria_1486.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1152_virus_1930.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person548_bacteria_2300.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person55_bacteria_263.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person494_virus_1000.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1429_bacteria_3688.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person294_bacteria_1385.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1530_bacteria_4000.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person38_bacteria_196.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1338_bacteria_3397.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person667_virus_1252.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1512_bacteria_3958.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1343_bacteria_3414.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person326_bacteria_1503.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person506_bacteria_2138.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1406_bacteria_3575.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1030_virus_1722.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person267_bacteria_1252.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person544_virus_1076.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person118_virus_224.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1669_bacteria_4422.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1405_bacteria_3567.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person375_virus_758.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1408_bacteria_3581.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1320_virus_2277.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person333_bacteria_1540.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person761_bacteria_2665.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person647_bacteria_2539.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1537_virus_2674.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1459_bacteria_3796.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1398_virus_2401.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person530_bacteria_2231.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person522_bacteria_2210.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1140_bacteria_3083.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1590_bacteria_4176.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person557_virus_1097.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1441_virus_2457.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1306_bacteria_3275.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/
jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person18_bacteria_57.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person460_bacteria_1958.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person376_virus_759.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1901_bacteria_4795.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1142_virus_1892.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person554_bacteria_2320.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person453_virus_935.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person374_bacteria_1711.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person23_bacteria_103.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1634_bacteria_4326.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1111_bacteria_3052.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1454_bacteria_3774.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1159_virus_1946.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1314_virus_2269.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person274_bacteria_1289.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person441_bacteria_1915.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person734_virus_1355.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1141_virus_1886.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1941_bacteria_4863.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1679_bacteria_4452.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1855_bacteria_4727.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1160_bacteria_3105.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1067_virus_1770.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person511_bacteria_2153.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person397_virus_790.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person114_virus_217.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person261_virus_543.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1300_virus_2240.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person736_bacteria_2639.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person925_virus_1582.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1816_bacteria_4674.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person564_bacteria_2343.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1608_bacteria_4235.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1119_virus_1844.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1638_bacteria_4341.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person51_bacteria_246.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1619_bacteria_4271.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1103_bacteria_3044.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1024_virus_1716.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1400_bacteria_3550.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1430_bacteria_3697.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1157_virus_1937.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1111_virus_1836.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person145_virus_295.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person278_virus_572.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person441_bacteria_1912.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person59_bacteria_279.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person351_bacteria_1620.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1636_bacteria_4337.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person25_bacteria_113.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person596_bacteria_2445.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1923_bacteria_4831.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1411_bacteria_3602.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person74_bacteria_361.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1311_virus_2257.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1375_bacteria_3509.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1549_virus_2690.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1051_bacteria_2985.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person949_bacteria_2874.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person520_bacteria_2203.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1265_bacteria_3223.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person929_virus_1589.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person104_virus_191.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1098_virus_1818.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person160_virus_316.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person806_virus_1440.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1486_bacteria_3881.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1414_virus_2424.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person624_virus_1198.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1277_bacteria_3240.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person344_virus_705.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person460_virus_948.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person23_bacteria_89.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person470_bacteria_1999.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person757_virus_1385.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1472_bacteria_3834.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person782_bacteria_2686.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person462_bacteria_1967.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1481_bacteria_3864.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1134_bacteria_3076.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person45_bacteria_222.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person548_virus_1088.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person125_virus_254.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1480_virus_2566.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person488_bacteria_2061.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person885_bacteria_2809.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person338_bacteria_1568.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1638_bacteria_4340.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person940_virus_1602.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person588_bacteria_2422.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person275_bacteria_1294.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1876_bacteria_4760.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1304_bacteria_3269.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1598_bacteria_4197.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1843_bacteria_4710.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person974_virus_1649.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1345_bacteria_3427.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1593_virus_2767.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person383_virus_767.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person348_virus_716.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1219_bacteria_3172.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1576_virus_2734.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person67_bacteria_331.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person509_virus_1024.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person483_virus_985.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1371_virus_2362.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person331_bacteria_1529.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1931_bacteria_4842.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person1600_bacteria_4202.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person527_bacteria_2225.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person970_bacteria_2895.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/person841_virus_1481.jpeg
# /home/ubuntu/teamprj/datasets/chest_xray/train/PNEUMONIA/.DS_Store
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-28-a5ff5628b1bb> in <module>
#       6 g_model = generator()
#       7 gan_model = define_gan(g_model, d_model)
# ----> 8 dataset = load_data(target_size=(IMG_SIZE,IMG_SIZE), img_folder='/home/ubuntu/teamprj/datasets/chest_xray/train')
#       9 train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs= n_epoch, n_batch= batch_size)
#
# <ipython-input-17-2a7bc262f9e6> in load_data(target_size, img_folder)
#      10             img = cv2.imread(imgpath)
#      11             print(imgpath)
# ---> 12             img = cv2.resize(img, target_size)
#      13             X.append(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#      14             Y.append(pneunomial_classes.index(pneumonial_type))
#
# error: OpenCV(4.5.2) /tmp/pip-req-build-x6vvo8fj/opencv/modules/imgproc/src/resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
